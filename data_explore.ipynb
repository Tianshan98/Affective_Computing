# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data
data = pd.read_csv('test_acc.csv')
data.describe()
# Out:
#                   x      distance             y             z         label
# count  30409.000000  30409.000000  30409.000000  30409.000000  30409.000000
# mean     -33.372456    -18.654802     11.803019      7.660103      0.353284
# std       18.972239     20.693462     35.580864     18.442304      0.477998
# min     -128.000000   -128.000000   -106.000000      0.000000      0.000000
# 25%      -49.000000    -39.000000    -18.000000      0.000000      0.000000
# 50%      -45.000000    -17.000000      2.000000      1.000000      0.000000
# 75%      -12.000000      0.000000     57.000000      2.449490      1.000000
# max      127.000000    127.000000    127.000000    211.094765      1.000000

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#load data
data = pd.read_csv('test.csv')
data.describe()
# Out:
#         timestamp  waist_conf    waist_tx    waist_ty    waist_tz    waist_rx  \
# count  314.000000  314.000000  314.000000  314.000000  314.000000  314.000000
# mean     5.216667    0.989682    8.155349  -31.281407 -215.965621   -0.575190
# std      3.026274    0.001759    4.120603    2.345088   48.001196    2.213622
# min      0.000000    0.980000    0.682570  -43.154040 -279.776280   -3.808070
# 25%      2.608333    0.990000    4.708845  -31.844472 -261.358612   -2.040172
# 50%      5.216665    0.990000    8.688105  -31.195600 -215.949150   -0.718460
# 75%      7.824998    0.990000   10.363810  -30.400502 -176.251992    0.589370
# max     10.433330    0.990000   17.711870  -27.651470 -121.304370    8.236620
#
#          waist_ry    waist_rz  chest_conf  chest_tx     ...      foreArm_R_rx  \
# count  314.000000  314.000000  314.000000     314.0     ...        314.000000
# mean    -1.114171    1.280509    0.988280       0.0     ...         -0.818670
# ...

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_ty'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_tz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
#waist
snsplot = sns.pairplot(data[['timestamp', 'waist_tx', 'waist_ty', 'waist_tz']])
#snsplot.savefig('waistt.png')

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_rx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_rx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_ry'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_ry', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['waist_rz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('waist_rz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.scatter(data['timestamp'], data['chest_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['chest_ty'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.scatter(data['timestamp'], data['chest_tz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_tz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['chest_rx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_rx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['chest_ry'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_ry', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['chest_rz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('chest_rz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_ty'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_tz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_tz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_rx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_rx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_ry'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_ry', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['upperLeg_L_rz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('upperLeg_L_rz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_ty'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_tz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_tz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_rx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_rx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_ry'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_ry', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['lowerLeg_L_rz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('lowerLeg_L_rz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_tx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_tx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_ty'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_ty', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_tz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_tz', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_rx'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_rx', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_ry'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_ry', fontsize = 14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.scatter(data['timestamp'], data['foot_L_rz'])
plt.xlabel('timestamp', fontsize = 14)
plt.ylabel('foot_L_rz', fontsize = 14)
plt.grid(True)
plt.show()
